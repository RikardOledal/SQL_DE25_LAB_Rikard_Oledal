# %% [markdown]
# # Lab 1 – SQL

# %% [markdown]
# Syftet med denna labb är att använda dina kunskaper i SQL och relationsdatabaser från kursen för att hitta insikter i DVD-uthyrningsdata. Du är dataanalytiker på ett DVD-uthyrningsföretag. Det finns äldre data lagrad i en SQLite-databas, och din chef ber dig att migrera den till DuckDB, analysera datan och presentera insikter för honom. Skapa ett offentligt GitHub-repo där du sparar allt arbete under projektets gång.

# %% [markdown]
# ## Uppgift 1 – EDA i Python
# - Skapa en Jupyter Notebook för analysera och visa datan för chefen
# - Resultaten ska synas i Notebooken.
#
# 1. Vilka filmer är längre än 3 timmar (180 minuter)?
#
# 2. Vilka filmer har ordet "love" i titeln?
#     - Visa dessa kolumner
#     - title
#     - rating
#     - length
#     - description
#
# 3. Beräkna följande för kolumnen length
#     - kortaste
#     - medel
#     - median
#     - längsta
#
# 4. Rental rate är kostnaden för att hyra en film och rental duration är antalet dagar kunden får behålla filmen. Chefen vill veta de 10 dyraste filmerna per dag att hyra.
#
# 5. Vilka skådespelare har medverkat i flest filmer? Visa topp 10 och antal filmer.
#
# 6. Nu får du ställa egna frågor till Sakila-databasen! Skriv 3–5 frågor du vill undersöka, och besvara dem med Pandas och DuckDB.

# %% [markdown]
# ## Uppgift 2 (Bonus) – Diagram
#
# I samma .ipynb-fil vill Chefen även se några meningsfulla diagram baserat på dina DataFrames.
#
# a) Vilka är våra topp 5 kunder baserat på total spenderad summa? Skapa ett stapeldiagram.
# b) Hur mycket pengar genererar varje filmgenre? Skapa ett stapeldiagram med total intäkt per kategori.
#
# Tips:
# Du behöver göra en join‐kedja:
# category → film_category → film → inventory → rental → payment

# %% [markdown]
# ## Uppgift 3 (Bonus) – BI-rapport
#
# I föreläsning 20_evidence_dashboard byggde vi en enkel dashboard med Evidence och DuckDB baserat på Sakila-data. The Manager vill att några av dina insikter från uppgift 1 och 2 ska inkluderas i dashboarden. Kombinera relevanta texter, tabeller och diagram.
# Känn dig fri att lägga till fler analyser och grafer.

# %% [markdown]
# ## Uppgift 4 – Video för stakeholder-presentation
#
# Skapa en video (5–10 minuter) där du spelar in skärmen och går igenom ditt repo och dina lösningar. Målgruppen är The Manager och hans datateam. Använd korrekt terminologi men håll det enkelt.
#
# Teamet har begränsat med tid, så håll dig till tidsgränsen. Har du gjort uppgift 3 ska du även presentera den i videon, med både demo och kort förklaring av kodstrukturen.
